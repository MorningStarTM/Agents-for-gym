# %%
import tensorflow as tf
import gym
from stable_baselines import ACER
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.evaluation import evaluate_policy
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\__init__.py:33: UserWarning: stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation.
#   "stable-baselines is in maintenance mode, please use [Stable-Baselines3 (SB3)](https://github.com/DLR-RM/stable-baselines3) for an up-to-date version. You can find a [migration guide](https://stable-baselines3.readthedocs.io/en/master/guide/migration.html) in SB3 documentation."

# %%
env = gym.make('LunarLander-v2')

# %%
for i in range(20):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
env.close()

# %%
#vectorize the environment
env = DummyVecEnv([lambda:env])
model = ACER('MlpPolicy', env, verbose=1)
# Out:
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\tensorflow_core\python\training\moving_averages.py:433: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\acer\acer_simple.py:421: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\acer\acer_simple.py:453: The name tf.global_norm is deprecated. Please use tf.linalg.global_norm instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\acer\acer_simple.py:479: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\acer\acer_simple.py:504: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From c:\Users\Dark-Devil\anaconda3\envs\rl_env\lib\site-packages\stable_baselines\acer\acer_simple.py:506: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
#train the model
model.learn(total_timesteps=1000000)
# Out:
# ----------------------------------
# | avg_norm_adj        | 0.455    |
# | avg_norm_g          | 3.77     |
# | avg_norm_grads_f    | 3.49     |
# | avg_norm_k          | 1.71     |
# | avg_norm_k_dot_g    | 3.77     |
# | entropy             | 5.93     |
# | explained_variance  | 0.51     |
# | fps                 | 0        |
# | loss                | 9.82     |
# | loss_bc             | -0       |
# | loss_f              | -0.13    |
# | loss_policy         | -0.13    |
# | loss_q              | 20       |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 31.7     |
# | norm_grads_policy   | 15.2     |
# | norm_grads_q        | 27.9     |
# | total_timesteps     | 20       |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0226   |
# | avg_norm_g          | 0.681    |
# | avg_norm_grads_f    | 0.652    |
# | avg_norm_k          | 7.11     |
# | avg_norm_k_dot_g    | 0.671    |
# | entropy             | 5.3      |
# | explained_variance  | 0.94     |
# | fps                 | 829      |
# | loss                | 0.0751   |
# | loss_bc             | -0       |
# | loss_f              | -0.0389  |
# | loss_policy         | -0.0389  |
# | loss_q              | 0.334    |
# | mean_episode_length | 281      |
# | mean_episode_reward | -17.6    |
# | norm_grads          | 16.8     |
# | norm_grads_policy   | 1.18     |
# | norm_grads_q        | 16.8     |
# | total_timesteps     | 2020     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 5.29     |
# | avg_norm_grads_f    | 5.29     |
# | avg_norm_k          | 2.99     |
# | avg_norm_k_dot_g    | 5.47     |
# | entropy             | 5.76     |
# | explained_variance  | -0.108   |
# | fps                 | 801      |
# | loss                | 6.27     |
# | loss_bc             | -0       |
# | loss_f              | 0.653    |
# | loss_policy         | 0.653    |
# | loss_q              | 11.3     |
# | mean_episode_length | 250      |
# | mean_episode_reward | -53.2    |
# | norm_grads          | 35.4     |
# | norm_grads_policy   | 10.6     |
# | norm_grads_q        | 33.8     |
# | total_timesteps     | 4020     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.91     |
# | avg_norm_grads_f    | 4.91     |
# | avg_norm_k          | 2.25     |
# | avg_norm_k_dot_g    | 5.43     |
# | entropy             | 6.47     |
# | explained_variance  | -0.0664  |
# | fps                 | 804      |
# | loss                | 5.28     |
# | loss_bc             | -0       |
# | loss_f              | 0.834    |
# | loss_policy         | 0.834    |
# | loss_q              | 9.01     |
# | mean_episode_length | 251      |
# | mean_episode_reward | -45      |
# | norm_grads          | 87       |
# | norm_grads_policy   | 37.3     |
# | norm_grads_q        | 78.6     |
# | total_timesteps     | 6020     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.323    |
# | avg_norm_g          | 2.2      |
# | avg_norm_grads_f    | 1.94     |
# | avg_norm_k          | 2.66     |
# | avg_norm_k_dot_g    | 2.19     |
# | entropy             | 5.73     |
# | explained_variance  | 0.321    |
# | fps                 | 779      |
# | loss                | 1.03     |
# | loss_bc             | -0       |
# | loss_f              | -0.149   |
# | loss_policy         | -0.149   |
# | loss_q              | 2.48     |
# | mean_episode_length | 278      |
# | mean_episode_reward | -33.7    |
# | norm_grads          | 26.6     |
# | norm_grads_policy   | 2.61     |
# | norm_grads_q        | 26.5     |
# | total_timesteps     | 8020     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 90.3     |
# | avg_norm_g          | 91.2     |
# | avg_norm_grads_f    | 0.922    |
# | avg_norm_k          | 1.06     |
# | avg_norm_k_dot_g    | 91.2     |
# | entropy             | 1.17     |
# | explained_variance  | 0.162    |
# | fps                 | 769      |
# | loss                | 2.47e+03 |
# | loss_bc             | -0       |
# | loss_f              | -0.00889 |
# | loss_policy         | -0.00889 |
# | loss_q              | 4.94e+03 |
# | mean_episode_length | 286      |
# | mean_episode_reward | -36.4    |
# | norm_grads          | 1.5e+03  |
# | norm_grads_policy   | 0.682    |
# | norm_grads_q        | 1.5e+03  |
# | total_timesteps     | 10020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.748    |
# | avg_norm_grads_f    | 0.748    |
# | avg_norm_k          | 139      |
# | avg_norm_k_dot_g    | 0.561    |
# | entropy             | 2.99     |
# | explained_variance  | 0.866    |
# | fps                 | 750      |
# | loss                | 0.155    |
# | loss_bc             | -0       |
# | loss_f              | 0.0129   |
# | loss_policy         | 0.0129   |
# | loss_q              | 0.343    |
# | mean_episode_length | 289      |
# | mean_episode_reward | -35.4    |
# | norm_grads          | 10.1     |
# | norm_grads_policy   | 2.52     |
# | norm_grads_q        | 9.82     |
# | total_timesteps     | 12020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 9.44     |
# | avg_norm_grads_f    | 9.44     |
# | avg_norm_k          | 1.59     |
# | avg_norm_k_dot_g    | 8.88     |
# | entropy             | 4.72     |
# | explained_variance  | -0.465   |
# | fps                 | 742      |
# | loss                | 18.9     |
# | loss_bc             | -0       |
# | loss_f              | 1.16     |
# | loss_policy         | 1.16     |
# | loss_q              | 35.5     |
# | mean_episode_length | 303      |
# | mean_episode_reward | -34.6    |
# | norm_grads          | 150      |
# | norm_grads_policy   | 48.5     |
# | norm_grads_q        | 142      |
# | total_timesteps     | 14020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 4.88e-05 |
# | avg_norm_g          | 1.57     |
# | avg_norm_grads_f    | 1.56     |
# | avg_norm_k          | 15.1     |
# | avg_norm_k_dot_g    | 1.09     |
# | entropy             | 5.56     |
# | explained_variance  | 0.197    |
# | fps                 | 734      |
# | loss                | 0.159    |
# | loss_bc             | -0       |
# | loss_f              | -0.169   |
# | loss_policy         | -0.169   |
# | loss_q              | 0.768    |
# | mean_episode_length | 307      |
# | mean_episode_reward | -20.3    |
# | norm_grads          | 10.6     |
# | norm_grads_policy   | 10.5     |
# | norm_grads_q        | 1.45     |
# | total_timesteps     | 16020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 6.72     |
# | avg_norm_grads_f    | 6.72     |
# | avg_norm_k          | 7.85     |
# | avg_norm_k_dot_g    | 6.14     |
# | entropy             | 3.79     |
# | explained_variance  | -0.00803 |
# | fps                 | 722      |
# | loss                | 9.77     |
# | loss_bc             | -0       |
# | loss_f              | 0.859    |
# | loss_policy         | 0.859    |
# | loss_q              | 17.9     |
# | mean_episode_length | 329      |
# | mean_episode_reward | -14.6    |
# | norm_grads          | 70.2     |
# | norm_grads_policy   | 20       |
# | norm_grads_q        | 67.3     |
# | total_timesteps     | 18020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.000614 |
# | avg_norm_g          | 4.03     |
# | avg_norm_grads_f    | 4.03     |
# | avg_norm_k          | 9.32     |
# | avg_norm_k_dot_g    | 10.3     |
# | entropy             | 7.74     |
# | explained_variance  | -0.0853  |
# | fps                 | 719      |
# | loss                | 2.73     |
# | loss_bc             | -0       |
# | loss_f              | 0.711    |
# | loss_policy         | 0.711    |
# | loss_q              | 4.19     |
# | mean_episode_length | 347      |
# | mean_episode_reward | -8.99    |
# | norm_grads          | 33.1     |
# | norm_grads_policy   | 20       |
# | norm_grads_q        | 26.3     |
# | total_timesteps     | 20020    |
# ----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.425     |
# | avg_norm_g          | 7.93      |
# | avg_norm_grads_f    | 7.49      |
# | avg_norm_k          | 19.4      |
# | avg_norm_k_dot_g    | 3.03      |
# | entropy             | 4.38      |
# | explained_variance  | -0.000877 |
# | fps                 | 714       |
# | loss                | 1.07      |
# | loss_bc             | -0        |
# | loss_f              | -0.752    |
# | loss_policy         | -0.752    |
# | loss_q              | 3.72      |
# | mean_episode_length | 366       |
# | mean_episode_reward | 1.25      |
# | norm_grads          | 28.2      |
# | norm_grads_policy   | 9.62      |
# | norm_grads_q        | 26.5      |
# | total_timesteps     | 22020     |
# -----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 5.86     |
# | avg_norm_grads_f    | 5.86     |
# | avg_norm_k          | 2.25     |
# | avg_norm_k_dot_g    | 5.39     |
# | entropy             | 7.43     |
# | explained_variance  | 0.627    |
# | fps                 | 694      |
# | loss                | 5.12     |
# | loss_bc             | -0       |
# | loss_f              | 1.17     |
# | loss_policy         | 1.17     |
# | loss_q              | 8.05     |
# | mean_episode_length | 379      |
# | mean_episode_reward | -2.15    |
# | norm_grads          | 109      |
# | norm_grads_policy   | 30.9     |
# | norm_grads_q        | 104      |
# | total_timesteps     | 24020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0644   |
# | avg_norm_g          | 1.48     |
# | avg_norm_grads_f    | 1.42     |
# | avg_norm_k          | 8.45     |
# | avg_norm_k_dot_g    | 1.78     |
# | entropy             | 3.66     |
# | explained_variance  | 0.174    |
# | fps                 | 688      |
# | loss                | 0.323    |
# | loss_bc             | -0       |
# | loss_f              | -0.176   |
# | loss_policy         | -0.176   |
# | loss_q              | 1.07     |
# | mean_episode_length | 396      |
# | mean_episode_reward | 2.12     |
# | norm_grads          | 18.1     |
# | norm_grads_policy   | 14.1     |
# | norm_grads_q        | 11.5     |
# | total_timesteps     | 26020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.881    |
# | avg_norm_g          | 2.99     |
# | avg_norm_grads_f    | 2.35     |
# | avg_norm_k          | 1.52     |
# | avg_norm_k_dot_g    | 2.98     |
# | entropy             | 3.46     |
# | explained_variance  | 0.176    |
# | fps                 | 681      |
# | loss                | 1.74     |
# | loss_bc             | -0       |
# | loss_f              | -0.322   |
# | loss_policy         | -0.322   |
# | loss_q              | 4.19     |
# | mean_episode_length | 414      |
# | mean_episode_reward | 10.1     |
# | norm_grads          | 46.8     |
# | norm_grads_policy   | 13.5     |
# | norm_grads_q        | 44.8     |
# | total_timesteps     | 28020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.496    |
# | avg_norm_g          | 16.1     |
# | avg_norm_grads_f    | 15.7     |
# | avg_norm_k          | 4.42     |
# | avg_norm_k_dot_g    | 16.3     |
# | entropy             | 7.28     |
# | explained_variance  | -0.573   |
# | fps                 | 672      |
# | loss                | 334      |
# | loss_bc             | -0       |
# | loss_f              | -0.254   |
# | loss_policy         | -0.254   |
# | loss_q              | 668      |
# | mean_episode_length | 419      |
# | mean_episode_reward | 22       |
# | norm_grads          | 80.4     |
# | norm_grads_policy   | 3.28     |
# | norm_grads_q        | 80.3     |
# | total_timesteps     | 30020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.163    |
# | avg_norm_g          | 1.83     |
# | avg_norm_grads_f    | 1.68     |
# | avg_norm_k          | 2.39     |
# | avg_norm_k_dot_g    | 2.57     |
# | entropy             | 5.34     |
# | explained_variance  | 0.866    |
# | fps                 | 661      |
# | loss                | -0.177   |
# | loss_bc             | -0       |
# | loss_f              | -0.355   |
# | loss_policy         | -0.355   |
# | loss_q              | 0.463    |
# | mean_episode_length | 441      |
# | mean_episode_reward | 32.5     |
# | norm_grads          | 7.1      |
# | norm_grads_policy   | 1.93     |
# | norm_grads_q        | 6.83     |
# | total_timesteps     | 32020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 1.94     |
# | avg_norm_grads_f    | 1.94     |
# | avg_norm_k          | 2.12     |
# | avg_norm_k_dot_g    | 2.37     |
# | entropy             | 4.22     |
# | explained_variance  | 0.914    |
# | fps                 | 650      |
# | loss                | 0.892    |
# | loss_bc             | -0       |
# | loss_f              | 0.208    |
# | loss_policy         | 0.208    |
# | loss_q              | 1.45     |
# | mean_episode_length | 471      |
# | mean_episode_reward | 33       |
# | norm_grads          | 35.9     |
# | norm_grads_policy   | 10.8     |
# | norm_grads_q        | 34.2     |
# | total_timesteps     | 34020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 6.72     |
# | avg_norm_grads_f    | 6.72     |
# | avg_norm_k          | 1.57     |
# | avg_norm_k_dot_g    | 6.51     |
# | entropy             | 5.28     |
# | explained_variance  | -0.226   |
# | fps                 | 647      |
# | loss                | 12.3     |
# | loss_bc             | -0       |
# | loss_f              | 0.407    |
# | loss_policy         | 0.407    |
# | loss_q              | 23.9     |
# | mean_episode_length | 474      |
# | mean_episode_reward | 20.4     |
# | norm_grads          | 135      |
# | norm_grads_policy   | 17.9     |
# | norm_grads_q        | 134      |
# | total_timesteps     | 36020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.47     |
# | avg_norm_g          | 3.3      |
# | avg_norm_grads_f    | 1.57     |
# | avg_norm_k          | 6.92     |
# | avg_norm_k_dot_g    | 3.84     |
# | entropy             | 5.81     |
# | explained_variance  | 0.873    |
# | fps                 | 644      |
# | loss                | 1.92     |
# | loss_bc             | -0       |
# | loss_f              | -0.392   |
# | loss_policy         | -0.392   |
# | loss_q              | 4.75     |
# | mean_episode_length | 481      |
# | mean_episode_reward | 20.2     |
# | norm_grads          | 63.7     |
# | norm_grads_policy   | 4.19     |
# | norm_grads_q        | 63.6     |
# | total_timesteps     | 38020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.014    |
# | avg_norm_g          | 0.483    |
# | avg_norm_grads_f    | 0.464    |
# | avg_norm_k          | 2.66     |
# | avg_norm_k_dot_g    | 0.627    |
# | entropy             | 3.89     |
# | explained_variance  | 0.926    |
# | fps                 | 643      |
# | loss                | 0.0308   |
# | loss_bc             | -0       |
# | loss_f              | 0.0066   |
# | loss_policy         | 0.0066   |
# | loss_q              | 0.126    |
# | mean_episode_length | 469      |
# | mean_episode_reward | 22.3     |
# | norm_grads          | 2.48     |
# | norm_grads_policy   | 1.37     |
# | norm_grads_q        | 2.07     |
# | total_timesteps     | 40020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.03     |
# | avg_norm_g          | 10.2     |
# | avg_norm_grads_f    | 8.09     |
# | avg_norm_k          | 1.82     |
# | avg_norm_k_dot_g    | 12.8     |
# | entropy             | 4.21     |
# | explained_variance  | -0.168   |
# | fps                 | 644      |
# | loss                | 1.78     |
# | loss_bc             | -0       |
# | loss_f              | -0.995   |
# | loss_policy         | -0.995   |
# | loss_q              | 5.64     |
# | mean_episode_length | 470      |
# | mean_episode_reward | 21.3     |
# | norm_grads          | 32.4     |
# | norm_grads_policy   | 12.9     |
# | norm_grads_q        | 29.7     |
# | total_timesteps     | 42020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.318    |
# | avg_norm_g          | 2.73     |
# | avg_norm_grads_f    | 2.03     |
# | avg_norm_k          | 6.93     |
# | avg_norm_k_dot_g    | 7.32     |
# | entropy             | 9.12     |
# | explained_variance  | 0.477    |
# | fps                 | 634      |
# | loss                | -0.0996  |
# | loss_bc             | -0       |
# | loss_f              | -0.384   |
# | loss_policy         | -0.384   |
# | loss_q              | 0.752    |
# | mean_episode_length | 469      |
# | mean_episode_reward | 21.7     |
# | norm_grads          | 12.7     |
# | norm_grads_policy   | 9.65     |
# | norm_grads_q        | 8.3      |
# | total_timesteps     | 44020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 33       |
# | avg_norm_grads_f    | 33       |
# | avg_norm_k          | 6.76     |
# | avg_norm_k_dot_g    | 20.9     |
# | entropy             | 2.45     |
# | explained_variance  | -5.13    |
# | fps                 | 626      |
# | loss                | 248      |
# | loss_bc             | -0       |
# | loss_f              | 4.84     |
# | loss_policy         | 4.84     |
# | loss_q              | 487      |
# | mean_episode_length | 473      |
# | mean_episode_reward | 33.2     |
# | norm_grads          | 258      |
# | norm_grads_policy   | 175      |
# | norm_grads_q        | 189      |
# | total_timesteps     | 46020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.893    |
# | avg_norm_g          | 4.74     |
# | avg_norm_grads_f    | 4.3      |
# | avg_norm_k          | 8.31     |
# | avg_norm_k_dot_g    | 2.15     |
# | entropy             | 7.25     |
# | explained_variance  | -0.0142  |
# | fps                 | 618      |
# | loss                | 0.267    |
# | loss_bc             | -0       |
# | loss_f              | -0.732   |
# | loss_policy         | -0.732   |
# | loss_q              | 2.14     |
# | mean_episode_length | 478      |
# | mean_episode_reward | 29.4     |
# | norm_grads          | 12.1     |
# | norm_grads_policy   | 7.78     |
# | norm_grads_q        | 9.22     |
# | total_timesteps     | 48020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 2.36     |
# | avg_norm_grads_f    | 2.36     |
# | avg_norm_k          | 3.89     |
# | avg_norm_k_dot_g    | 2.14     |
# | entropy             | 4.96     |
# | explained_variance  | 0.21     |
# | fps                 | 615      |
# | loss                | 1.63     |
# | loss_bc             | -0       |
# | loss_f              | 0.119    |
# | loss_policy         | 0.119    |
# | loss_q              | 3.12     |
# | mean_episode_length | 502      |
# | mean_episode_reward | 13.6     |
# | norm_grads          | 34.2     |
# | norm_grads_policy   | 3.7      |
# | norm_grads_q        | 34       |
# | total_timesteps     | 50020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 6.45     |
# | avg_norm_grads_f    | 6.45     |
# | avg_norm_k          | 6.51     |
# | avg_norm_k_dot_g    | 6.29     |
# | entropy             | 9.11     |
# | explained_variance  | -0.111   |
# | fps                 | 616      |
# | loss                | 4.07     |
# | loss_bc             | -0       |
# | loss_f              | 1.49     |
# | loss_policy         | 1.49     |
# | loss_q              | 5.34     |
# | mean_episode_length | 496      |
# | mean_episode_reward | 10.1     |
# | norm_grads          | 89.6     |
# | norm_grads_policy   | 68.8     |
# | norm_grads_q        | 57.5     |
# | total_timesteps     | 52020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.05     |
# | avg_norm_g          | 3.36     |
# | avg_norm_grads_f    | 2.4      |
# | avg_norm_k          | 1.91     |
# | avg_norm_k_dot_g    | 3.8      |
# | entropy             | 4.75     |
# | explained_variance  | 0.33     |
# | fps                 | 615      |
# | loss                | 1.3      |
# | loss_bc             | -0       |
# | loss_f              | -0.496   |
# | loss_policy         | -0.496   |
# | loss_q              | 3.69     |
# | mean_episode_length | 518      |
# | mean_episode_reward | 20.5     |
# | norm_grads          | 52.6     |
# | norm_grads_policy   | 12.1     |
# | norm_grads_q        | 51.2     |
# | total_timesteps     | 54020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.641    |
# | avg_norm_g          | 3.42     |
# | avg_norm_grads_f    | 2.53     |
# | avg_norm_k          | 3.93     |
# | avg_norm_k_dot_g    | 7.65     |
# | entropy             | 6.15     |
# | explained_variance  | 0.237    |
# | fps                 | 612      |
# | loss                | 0.913    |
# | loss_bc             | -0       |
# | loss_f              | -0.494   |
# | loss_policy         | -0.494   |
# | loss_q              | 2.94     |
# | mean_episode_length | 519      |
# | mean_episode_reward | 20.4     |
# | norm_grads          | 15.9     |
# | norm_grads_policy   | 6.94     |
# | norm_grads_q        | 14.3     |
# | total_timesteps     | 56020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.392    |
# | avg_norm_g          | 1.77     |
# | avg_norm_grads_f    | 1.39     |
# | avg_norm_k          | 1.91     |
# | avg_norm_k_dot_g    | 2.25     |
# | entropy             | 4.05     |
# | explained_variance  | 0.765    |
# | fps                 | 616      |
# | loss                | 0.0759   |
# | loss_bc             | -0       |
# | loss_f              | -0.205   |
# | loss_policy         | -0.205   |
# | loss_q              | 0.643    |
# | mean_episode_length | 494      |
# | mean_episode_reward | 14.2     |
# | norm_grads          | 19.9     |
# | norm_grads_policy   | 9.25     |
# | norm_grads_q        | 17.6     |
# | total_timesteps     | 58020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.00284  |
# | avg_norm_g          | 0.391    |
# | avg_norm_grads_f    | 0.389    |
# | avg_norm_k          | 1.54     |
# | avg_norm_k_dot_g    | 0.377    |
# | entropy             | 4.33     |
# | explained_variance  | 0.948    |
# | fps                 | 612      |
# | loss                | -0.00748 |
# | loss_bc             | -0       |
# | loss_f              | -0.0234  |
# | loss_policy         | -0.0234  |
# | loss_q              | 0.118    |
# | mean_episode_length | 516      |
# | mean_episode_reward | 13.4     |
# | norm_grads          | 2.7      |
# | norm_grads_policy   | 0.309    |
# | norm_grads_q        | 2.68     |
# | total_timesteps     | 60020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0226   |
# | avg_norm_g          | 5.86     |
# | avg_norm_grads_f    | 5.84     |
# | avg_norm_k          | 2.55     |
# | avg_norm_k_dot_g    | 6.55     |
# | entropy             | 3.02     |
# | explained_variance  | 0.691    |
# | fps                 | 610      |
# | loss                | 1.57     |
# | loss_bc             | -0       |
# | loss_f              | 0.523    |
# | loss_policy         | 0.523    |
# | loss_q              | 2.16     |
# | mean_episode_length | 531      |
# | mean_episode_reward | 17.9     |
# | norm_grads          | 35.5     |
# | norm_grads_policy   | 21       |
# | norm_grads_q        | 28.6     |
# | total_timesteps     | 62020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0232   |
# | avg_norm_g          | 10.8     |
# | avg_norm_grads_f    | 10.7     |
# | avg_norm_k          | 2.5      |
# | avg_norm_k_dot_g    | 11.3     |
# | entropy             | 8.66     |
# | explained_variance  | -1.03    |
# | fps                 | 608      |
# | loss                | 3.5      |
# | loss_bc             | -0       |
# | loss_f              | 1.55     |
# | loss_policy         | 1.55     |
# | loss_q              | 4.08     |
# | mean_episode_length | 515      |
# | mean_episode_reward | 14       |
# | norm_grads          | 34.4     |
# | norm_grads_policy   | 27.8     |
# | norm_grads_q        | 20.3     |
# | total_timesteps     | 64020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.67     |
# | avg_norm_g          | 5.75     |
# | avg_norm_grads_f    | 4.77     |
# | avg_norm_k          | 3.43     |
# | avg_norm_k_dot_g    | 5.1      |
# | entropy             | 4.29     |
# | explained_variance  | -0.394   |
# | fps                 | 603      |
# | loss                | 5.19     |
# | loss_bc             | -0       |
# | loss_f              | -0.709   |
# | loss_policy         | -0.709   |
# | loss_q              | 11.9     |
# | mean_episode_length | 546      |
# | mean_episode_reward | 15.7     |
# | norm_grads          | 109      |
# | norm_grads_policy   | 44.9     |
# | norm_grads_q        | 98.8     |
# | total_timesteps     | 66020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 1.82     |
# | avg_norm_grads_f    | 1.82     |
# | avg_norm_k          | 14.5     |
# | avg_norm_k_dot_g    | 2.38     |
# | entropy             | 5.04     |
# | explained_variance  | 0.853    |
# | fps                 | 600      |
# | loss                | 0.813    |
# | loss_bc             | -0       |
# | loss_f              | 0.271    |
# | loss_policy         | 0.271    |
# | loss_q              | 1.18     |
# | mean_episode_length | 542      |
# | mean_episode_reward | 1.3      |
# | norm_grads          | 17.8     |
# | norm_grads_policy   | 7.74     |
# | norm_grads_q        | 16       |
# | total_timesteps     | 68020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0408   |
# | avg_norm_g          | 1.52     |
# | avg_norm_grads_f    | 1.48     |
# | avg_norm_k          | 3.12     |
# | avg_norm_k_dot_g    | 1.46     |
# | entropy             | 4.27     |
# | explained_variance  | 0.629    |
# | fps                 | 596      |
# | loss                | 0.76     |
# | loss_bc             | -0       |
# | loss_f              | 0.0889   |
# | loss_policy         | 0.0889   |
# | loss_q              | 1.43     |
# | mean_episode_length | 565      |
# | mean_episode_reward | 4.2      |
# | norm_grads          | 14.6     |
# | norm_grads_policy   | 3.6      |
# | norm_grads_q        | 14.1     |
# | total_timesteps     | 70020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 7.35e-05 |
# | avg_norm_g          | 1.26     |
# | avg_norm_grads_f    | 1.26     |
# | avg_norm_k          | 4.59     |
# | avg_norm_k_dot_g    | 1.22     |
# | entropy             | 3.45     |
# | explained_variance  | 0.172    |
# | fps                 | 591      |
# | loss                | 0.49     |
# | loss_bc             | -0       |
# | loss_f              | 0.0307   |
# | loss_policy         | 0.0307   |
# | loss_q              | 0.988    |
# | mean_episode_length | 557      |
# | mean_episode_reward | 16.7     |
# | norm_grads          | 12.6     |
# | norm_grads_policy   | 2.11     |
# | norm_grads_q        | 12.4     |
# | total_timesteps     | 72020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.636    |
# | avg_norm_g          | 4.28     |
# | avg_norm_grads_f    | 3.79     |
# | avg_norm_k          | 14.4     |
# | avg_norm_k_dot_g    | 2.93     |
# | entropy             | 3.71     |
# | explained_variance  | -0.488   |
# | fps                 | 589      |
# | loss                | 3.01     |
# | loss_bc             | -0       |
# | loss_f              | -0.485   |
# | loss_policy         | -0.485   |
# | loss_q              | 7.07     |
# | mean_episode_length | 545      |
# | mean_episode_reward | 14.3     |
# | norm_grads          | 64.9     |
# | norm_grads_policy   | 25.8     |
# | norm_grads_q        | 59.6     |
# | total_timesteps     | 74020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0503   |
# | avg_norm_g          | 3.52     |
# | avg_norm_grads_f    | 3.49     |
# | avg_norm_k          | 2.07     |
# | avg_norm_k_dot_g    | 3.68     |
# | entropy             | 7.47     |
# | explained_variance  | 0.738    |
# | fps                 | 588      |
# | loss                | 1.33     |
# | loss_bc             | -0       |
# | loss_f              | 0.626    |
# | loss_policy         | 0.626    |
# | loss_q              | 1.55     |
# | mean_episode_length | 573      |
# | mean_episode_reward | 13.7     |
# | norm_grads          | 14.5     |
# | norm_grads_policy   | 7.98     |
# | norm_grads_q        | 12.1     |
# | total_timesteps     | 76020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0085   |
# | avg_norm_g          | 0.621    |
# | avg_norm_grads_f    | 0.613    |
# | avg_norm_k          | 2.2      |
# | avg_norm_k_dot_g    | 0.681    |
# | entropy             | 4.82     |
# | explained_variance  | 0.927    |
# | fps                 | 585      |
# | loss                | 0.0883   |
# | loss_bc             | -0       |
# | loss_f              | 0.0538   |
# | loss_policy         | 0.0538   |
# | loss_q              | 0.165    |
# | mean_episode_length | 577      |
# | mean_episode_reward | 13.1     |
# | norm_grads          | 1.66     |
# | norm_grads_policy   | 1.61     |
# | norm_grads_q        | 0.431    |
# | total_timesteps     | 78020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.16     |
# | avg_norm_g          | 3.4      |
# | avg_norm_grads_f    | 3.25     |
# | avg_norm_k          | 2.61     |
# | avg_norm_k_dot_g    | 2.86     |
# | entropy             | 4.78     |
# | explained_variance  | -1.54    |
# | fps                 | 584      |
# | loss                | 2.46     |
# | loss_bc             | -0       |
# | loss_f              | 0.39     |
# | loss_policy         | 0.39     |
# | loss_q              | 4.24     |
# | mean_episode_length | 596      |
# | mean_episode_reward | 1.29     |
# | norm_grads          | 14.4     |
# | norm_grads_policy   | 9.77     |
# | norm_grads_q        | 10.6     |
# | total_timesteps     | 80020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 4.87e-05 |
# | avg_norm_g          | 1.6      |
# | avg_norm_grads_f    | 1.6      |
# | avg_norm_k          | 2.93     |
# | avg_norm_k_dot_g    | 1.72     |
# | entropy             | 6.44     |
# | explained_variance  | 0.389    |
# | fps                 | 579      |
# | loss                | 0.886    |
# | loss_bc             | -0       |
# | loss_f              | 0.234    |
# | loss_policy         | 0.234    |
# | loss_q              | 1.43     |
# | mean_episode_length | 636      |
# | mean_episode_reward | 3.75     |
# | norm_grads          | 21       |
# | norm_grads_policy   | 14.4     |
# | norm_grads_q        | 15.3     |
# | total_timesteps     | 82020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.662    |
# | avg_norm_g          | 18.1     |
# | avg_norm_grads_f    | 17.7     |
# | avg_norm_k          | 3.37     |
# | avg_norm_k_dot_g    | 12       |
# | entropy             | 5.95     |
# | explained_variance  | 0.305    |
# | fps                 | 577      |
# | loss                | 263      |
# | loss_bc             | -0       |
# | loss_f              | -3.82    |
# | loss_policy         | -3.82    |
# | loss_q              | 534      |
# | mean_episode_length | 675      |
# | mean_episode_reward | 9.87     |
# | norm_grads          | 380      |
# | norm_grads_policy   | 335      |
# | norm_grads_q        | 178      |
# | total_timesteps     | 84020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.000762 |
# | avg_norm_g          | 1.21     |
# | avg_norm_grads_f    | 1.21     |
# | avg_norm_k          | 11.9     |
# | avg_norm_k_dot_g    | 1.93     |
# | entropy             | 4.06     |
# | explained_variance  | 0.76     |
# | fps                 | 578      |
# | loss                | 0.277    |
# | loss_bc             | -0       |
# | loss_f              | 0.111    |
# | loss_policy         | 0.111    |
# | loss_q              | 0.413    |
# | mean_episode_length | 692      |
# | mean_episode_reward | 11.6     |
# | norm_grads          | 3.28     |
# | norm_grads_policy   | 2.74     |
# | norm_grads_q        | 1.81     |
# | total_timesteps     | 86020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.224    |
# | avg_norm_g          | 1.81     |
# | avg_norm_grads_f    | 1.27     |
# | avg_norm_k          | 4.89     |
# | avg_norm_k_dot_g    | 3.41     |
# | entropy             | 7.74     |
# | explained_variance  | 0.556    |
# | fps                 | 576      |
# | loss                | -0.18    |
# | loss_bc             | -0       |
# | loss_f              | -0.354   |
# | loss_policy         | -0.354   |
# | loss_q              | 0.502    |
# | mean_episode_length | 677      |
# | mean_episode_reward | 2.52     |
# | norm_grads          | 6.74     |
# | norm_grads_policy   | 4.59     |
# | norm_grads_q        | 4.93     |
# | total_timesteps     | 88020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.399    |
# | avg_norm_g          | 2.69     |
# | avg_norm_grads_f    | 2        |
# | avg_norm_k          | 2.67     |
# | avg_norm_k_dot_g    | 5.37     |
# | entropy             | 7.56     |
# | explained_variance  | -0.633   |
# | fps                 | 577      |
# | loss                | 0.118    |
# | loss_bc             | -0       |
# | loss_f              | -0.188   |
# | loss_policy         | -0.188   |
# | loss_q              | 0.762    |
# | mean_episode_length | 688      |
# | mean_episode_reward | 3.1      |
# | norm_grads          | 10       |
# | norm_grads_policy   | 3.05     |
# | norm_grads_q        | 9.52     |
# | total_timesteps     | 90020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.183    |
# | avg_norm_g          | 2.16     |
# | avg_norm_grads_f    | 1.94     |
# | avg_norm_k          | 13.4     |
# | avg_norm_k_dot_g    | 1.17     |
# | entropy             | 6.36     |
# | explained_variance  | 0.071    |
# | fps                 | 577      |
# | loss                | 0.511    |
# | loss_bc             | -0       |
# | loss_f              | -0.342   |
# | loss_policy         | -0.342   |
# | loss_q              | 1.83     |
# | mean_episode_length | 691      |
# | mean_episode_reward | -5.18    |
# | norm_grads          | 30.4     |
# | norm_grads_policy   | 22.1     |
# | norm_grads_q        | 20.9     |
# | total_timesteps     | 92020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0112   |
# | avg_norm_g          | 1.92     |
# | avg_norm_grads_f    | 1.91     |
# | avg_norm_k          | 5.89     |
# | avg_norm_k_dot_g    | 1.76     |
# | entropy             | 5        |
# | explained_variance  | 0.326    |
# | fps                 | 577      |
# | loss                | 1.26     |
# | loss_bc             | -0       |
# | loss_f              | 0.148    |
# | loss_policy         | 0.148    |
# | loss_q              | 2.32     |
# | mean_episode_length | 690      |
# | mean_episode_reward | -13      |
# | norm_grads          | 18.6     |
# | norm_grads_policy   | 5        |
# | norm_grads_q        | 17.9     |
# | total_timesteps     | 94020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 2.54     |
# | avg_norm_g          | 6.05     |
# | avg_norm_grads_f    | 4.16     |
# | avg_norm_k          | 1.98     |
# | avg_norm_k_dot_g    | 5.81     |
# | entropy             | 2.52     |
# | explained_variance  | -1.01    |
# | fps                 | 576      |
# | loss                | 9.43     |
# | loss_bc             | -0       |
# | loss_f              | -0.224   |
# | loss_policy         | -0.224   |
# | loss_q              | 19.4     |
# | mean_episode_length | 699      |
# | mean_episode_reward | -11.4    |
# | norm_grads          | 91.2     |
# | norm_grads_policy   | 10.2     |
# | norm_grads_q        | 90.6     |
# | total_timesteps     | 96020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.14     |
# | avg_norm_g          | 1.25     |
# | avg_norm_grads_f    | 0.874    |
# | avg_norm_k          | 7.56     |
# | avg_norm_k_dot_g    | 2.35     |
# | entropy             | 3.83     |
# | explained_variance  | 0.909    |
# | fps                 | 573      |
# | loss                | 0.0588   |
# | loss_bc             | -0       |
# | loss_f              | -0.16    |
# | loss_policy         | -0.16    |
# | loss_q              | 0.514    |
# | mean_episode_length | 700      |
# | mean_episode_reward | -12      |
# | norm_grads          | 14.4     |
# | norm_grads_policy   | 0.319    |
# | norm_grads_q        | 14.4     |
# | total_timesteps     | 98020    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.026    |
# | avg_norm_g          | 1.12     |
# | avg_norm_grads_f    | 1.1      |
# | avg_norm_k          | 4.7      |
# | avg_norm_k_dot_g    | 1.4      |
# | entropy             | 4.27     |
# | explained_variance  | 0.8      |
# | fps                 | 573      |
# | loss                | 0.364    |
# | loss_bc             | -0       |
# | loss_f              | 0.0999   |
# | loss_policy         | 0.0999   |
# | loss_q              | 0.615    |
# | mean_episode_length | 702      |
# | mean_episode_reward | -18.1    |
# | norm_grads          | 13       |
# | norm_grads_policy   | 5.59     |
# | norm_grads_q        | 11.8     |
# | total_timesteps     | 100020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.959    |
# | avg_norm_g          | 5.23     |
# | avg_norm_grads_f    | 4.61     |
# | avg_norm_k          | 2.14     |
# | avg_norm_k_dot_g    | 4.83     |
# | entropy             | 9.46     |
# | explained_variance  | -0.0642  |
# | fps                 | 571      |
# | loss                | 0.459    |
# | loss_bc             | -0       |
# | loss_f              | -1.17    |
# | loss_policy         | -1.17    |
# | loss_q              | 3.44     |
# | mean_episode_length | 734      |
# | mean_episode_reward | -12.9    |
# | norm_grads          | 31.9     |
# | norm_grads_policy   | 18.6     |
# | norm_grads_q        | 26       |
# | total_timesteps     | 102020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.192    |
# | avg_norm_g          | 1.67     |
# | avg_norm_grads_f    | 1.52     |
# | avg_norm_k          | 3.89     |
# | avg_norm_k_dot_g    | 1.72     |
# | entropy             | 6.54     |
# | explained_variance  | 0.498    |
# | fps                 | 568      |
# | loss                | 0.266    |
# | loss_bc             | -0       |
# | loss_f              | -0.188   |
# | loss_policy         | -0.188   |
# | loss_q              | 1.04     |
# | mean_episode_length | 746      |
# | mean_episode_reward | -21      |
# | norm_grads          | 19.4     |
# | norm_grads_policy   | 10.8     |
# | norm_grads_q        | 16.2     |
# | total_timesteps     | 104020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.117    |
# | avg_norm_g          | 1.54     |
# | avg_norm_grads_f    | 1.45     |
# | avg_norm_k          | 2.28     |
# | avg_norm_k_dot_g    | 1.33     |
# | entropy             | 9.31     |
# | explained_variance  | 0.833    |
# | fps                 | 567      |
# | loss                | -0.181   |
# | loss_bc             | -0       |
# | loss_f              | -0.372   |
# | loss_policy         | -0.372   |
# | loss_q              | 0.568    |
# | mean_episode_length | 748      |
# | mean_episode_reward | -13.6    |
# | norm_grads          | 18.5     |
# | norm_grads_policy   | 7.94     |
# | norm_grads_q        | 16.7     |
# | total_timesteps     | 106020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.145    |
# | avg_norm_g          | 1.59     |
# | avg_norm_grads_f    | 1.38     |
# | avg_norm_k          | 3.68     |
# | avg_norm_k_dot_g    | 1.23     |
# | entropy             | 8.35     |
# | explained_variance  | 0.535    |
# | fps                 | 563      |
# | loss                | 0.0366   |
# | loss_bc             | -0       |
# | loss_f              | -0.284   |
# | loss_policy         | -0.284   |
# | loss_q              | 0.808    |
# | mean_episode_length | 762      |
# | mean_episode_reward | -23.5    |
# | norm_grads          | 12.7     |
# | norm_grads_policy   | 12.4     |
# | norm_grads_q        | 2.85     |
# | total_timesteps     | 108020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 2.39     |
# | avg_norm_g          | 7.56     |
# | avg_norm_grads_f    | 5.21     |
# | avg_norm_k          | 2.28     |
# | avg_norm_k_dot_g    | 7.9      |
# | entropy             | 4.54     |
# | explained_variance  | -0.567   |
# | fps                 | 564      |
# | loss                | 5.61     |
# | loss_bc             | -0       |
# | loss_f              | -1.15    |
# | loss_policy         | -1.15    |
# | loss_q              | 13.6     |
# | mean_episode_length | 744      |
# | mean_episode_reward | -31.1    |
# | norm_grads          | 81       |
# | norm_grads_policy   | 22.1     |
# | norm_grads_q        | 77.9     |
# | total_timesteps     | 110020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.181    |
# | avg_norm_g          | 2.63     |
# | avg_norm_grads_f    | 2.35     |
# | avg_norm_k          | 1.85     |
# | avg_norm_k_dot_g    | 3.24     |
# | entropy             | 2.68     |
# | explained_variance  | 0.778    |
# | fps                 | 564      |
# | loss                | 0.0862   |
# | loss_bc             | -0       |
# | loss_f              | -0.0356  |
# | loss_policy         | -0.0356  |
# | loss_q              | 0.297    |
# | mean_episode_length | 747      |
# | mean_episode_reward | -36      |
# | norm_grads          | 7.6      |
# | norm_grads_policy   | 6.01     |
# | norm_grads_q        | 4.64     |
# | total_timesteps     | 112020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.172    |
# | avg_norm_g          | 1.93     |
# | avg_norm_grads_f    | 1.79     |
# | avg_norm_k          | 3.33     |
# | avg_norm_k_dot_g    | 1.98     |
# | entropy             | 7.34     |
# | explained_variance  | -0.0388  |
# | fps                 | 564      |
# | loss                | 0.682    |
# | loss_bc             | -0       |
# | loss_f              | -0.252   |
# | loss_policy         | -0.252   |
# | loss_q              | 2.01     |
# | mean_episode_length | 728      |
# | mean_episode_reward | -43.3    |
# | norm_grads          | 16.3     |
# | norm_grads_policy   | 5.91     |
# | norm_grads_q        | 15.2     |
# | total_timesteps     | 114020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.443    |
# | avg_norm_g          | 3.25     |
# | avg_norm_grads_f    | 2.77     |
# | avg_norm_k          | 10.5     |
# | avg_norm_k_dot_g    | 2.72     |
# | entropy             | 6.38     |
# | explained_variance  | 0.521    |
# | fps                 | 563      |
# | loss                | 0.641    |
# | loss_bc             | -0       |
# | loss_f              | -0.628   |
# | loss_policy         | -0.628   |
# | loss_q              | 2.67     |
# | mean_episode_length | 732      |
# | mean_episode_reward | -49.7    |
# | norm_grads          | 29.2     |
# | norm_grads_policy   | 6.86     |
# | norm_grads_q        | 28.4     |
# | total_timesteps     | 116020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.77     |
# | avg_norm_g          | 6.03     |
# | avg_norm_grads_f    | 4.75     |
# | avg_norm_k          | 2.09     |
# | avg_norm_k_dot_g    | 4.35     |
# | entropy             | 9.48     |
# | explained_variance  | -0.0208  |
# | fps                 | 562      |
# | loss                | 3.79     |
# | loss_bc             | -0       |
# | loss_f              | -1.26    |
# | loss_policy         | -1.26    |
# | loss_q              | 10.3     |
# | mean_episode_length | 765      |
# | mean_episode_reward | -50.5    |
# | norm_grads          | 64.6     |
# | norm_grads_policy   | 52.3     |
# | norm_grads_q        | 38       |
# | total_timesteps     | 118020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.96     |
# | avg_norm_grads_f    | 4.96     |
# | avg_norm_k          | 1.73     |
# | avg_norm_k_dot_g    | 4.59     |
# | entropy             | 4.72     |
# | explained_variance  | -0.0677  |
# | fps                 | 560      |
# | loss                | 6.83     |
# | loss_bc             | -0       |
# | loss_f              | 0.428    |
# | loss_policy         | 0.428    |
# | loss_q              | 12.9     |
# | mean_episode_length | 766      |
# | mean_episode_reward | -59.9    |
# | norm_grads          | 69.7     |
# | norm_grads_policy   | 27.2     |
# | norm_grads_q        | 64.2     |
# | total_timesteps     | 120020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.579    |
# | avg_norm_g          | 3.81     |
# | avg_norm_grads_f    | 3.38     |
# | avg_norm_k          | 2.45     |
# | avg_norm_k_dot_g    | 3.76     |
# | entropy             | 6.41     |
# | explained_variance  | -0.458   |
# | fps                 | 558      |
# | loss                | 2.85     |
# | loss_bc             | -0       |
# | loss_f              | -0.328   |
# | loss_policy         | -0.328   |
# | loss_q              | 6.49     |
# | mean_episode_length | 780      |
# | mean_episode_reward | -60.6    |
# | norm_grads          | 37.9     |
# | norm_grads_policy   | 9.31     |
# | norm_grads_q        | 36.7     |
# | total_timesteps     | 122020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 2.09     |
# | avg_norm_g          | 30.3     |
# | avg_norm_grads_f    | 29.1     |
# | avg_norm_k          | 2.99     |
# | avg_norm_k_dot_g    | 26.2     |
# | entropy             | 5.46     |
# | explained_variance  | 0.316    |
# | fps                 | 557      |
# | loss                | 455      |
# | loss_bc             | -0       |
# | loss_f              | -0.146   |
# | loss_policy         | -0.146   |
# | loss_q              | 909      |
# | mean_episode_length | 797      |
# | mean_episode_reward | -68.1    |
# | norm_grads          | 215      |
# | norm_grads_policy   | 152      |
# | norm_grads_q        | 152      |
# | total_timesteps     | 124020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0289   |
# | avg_norm_g          | 9.7      |
# | avg_norm_grads_f    | 9.67     |
# | avg_norm_k          | 2.52     |
# | avg_norm_k_dot_g    | 6.79     |
# | entropy             | 3.13     |
# | explained_variance  | -0.301   |
# | fps                 | 554      |
# | loss                | 12.3     |
# | loss_bc             | -0       |
# | loss_f              | 1.6      |
# | loss_policy         | 1.6      |
# | loss_q              | 21.4     |
# | mean_episode_length | 808      |
# | mean_episode_reward | -69.5    |
# | norm_grads          | 47.3     |
# | norm_grads_policy   | 35.5     |
# | norm_grads_q        | 31.3     |
# | total_timesteps     | 126020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 4.32     |
# | avg_norm_grads_f    | 4.32     |
# | avg_norm_k          | 2.69     |
# | avg_norm_k_dot_g    | 3.57     |
# | entropy             | 5.45     |
# | explained_variance  | 0.656    |
# | fps                 | 553      |
# | loss                | 4.36     |
# | loss_bc             | -0       |
# | loss_f              | 0.569    |
# | loss_policy         | 0.569    |
# | loss_q              | 7.69     |
# | mean_episode_length | 808      |
# | mean_episode_reward | -74      |
# | norm_grads          | 33.6     |
# | norm_grads_policy   | 18.7     |
# | norm_grads_q        | 27.9     |
# | total_timesteps     | 128020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 12.3     |
# | avg_norm_grads_f    | 12.3     |
# | avg_norm_k          | 1.68     |
# ...
# | avg_norm_k_dot_g    | 1.58     |
# | entropy             | 2.8      |
# | explained_variance  | 0.842    |
# | fps                 | 477      |
# | loss                | 0.424    |
# | loss_bc             | -0       |
# | loss_f              | 0.184    |
# | loss_policy         | 0.184    |
# | loss_q              | 0.537    |
# | mean_episode_length | 346      |
# | mean_episode_reward | 113      |
# | norm_grads          | 10.8     |
# | norm_grads_policy   | 10.5     |
# | norm_grads_q        | 2.57     |
# | total_timesteps     | 956020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.924    |
# | avg_norm_grads_f    | 0.924    |
# | avg_norm_k          | 1.73     |
# | avg_norm_k_dot_g    | 0.925    |
# | entropy             | 2.78     |
# | explained_variance  | 0.847    |
# | fps                 | 477      |
# | loss                | 0.307    |
# | loss_bc             | -0       |
# | loss_f              | 0.0924   |
# | loss_policy         | 0.0924   |
# | loss_q              | 0.485    |
# | mean_episode_length | 328      |
# | mean_episode_reward | 118      |
# | norm_grads          | 12.2     |
# | norm_grads_policy   | 4.72     |
# | norm_grads_q        | 11.3     |
# | total_timesteps     | 958020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 1.2      |
# | avg_norm_grads_f    | 1.2      |
# | avg_norm_k          | 1.93     |
# | avg_norm_k_dot_g    | 1.2      |
# | entropy             | 3.83     |
# | explained_variance  | 0.722    |
# | fps                 | 477      |
# | loss                | 0.456    |
# | loss_bc             | -0       |
# | loss_f              | 0.0994   |
# | loss_policy         | 0.0994   |
# | loss_q              | 0.79     |
# | mean_episode_length | 321      |
# | mean_episode_reward | 122      |
# | norm_grads          | 18.2     |
# | norm_grads_policy   | 2.54     |
# | norm_grads_q        | 18       |
# | total_timesteps     | 960020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.169    |
# | avg_norm_g          | 1.35     |
# | avg_norm_grads_f    | 1.23     |
# | avg_norm_k          | 1.61     |
# | avg_norm_k_dot_g    | 1.36     |
# | entropy             | 4.27     |
# | explained_variance  | 0.775    |
# | fps                 | 477      |
# | loss                | 0.0716   |
# | loss_bc             | -0       |
# | loss_f              | -0.136   |
# | loss_policy         | -0.136   |
# | loss_q              | 0.501    |
# | mean_episode_length | 318      |
# | mean_episode_reward | 121      |
# | norm_grads          | 7.81     |
# | norm_grads_policy   | 2.66     |
# | norm_grads_q        | 7.34     |
# | total_timesteps     | 962020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0714   |
# | avg_norm_g          | 2.15     |
# | avg_norm_grads_f    | 2.1      |
# | avg_norm_k          | 1.42     |
# | avg_norm_k_dot_g    | 2.15     |
# | entropy             | 6.97     |
# | explained_variance  | 0.274    |
# | fps                 | 477      |
# | loss                | 1.22     |
# | loss_bc             | -0       |
# | loss_f              | 0.0851   |
# | loss_policy         | 0.0851   |
# | loss_q              | 2.4      |
# | mean_episode_length | 332      |
# | mean_episode_reward | 119      |
# | norm_grads          | 19.6     |
# | norm_grads_policy   | 2.65     |
# | norm_grads_q        | 19.4     |
# | total_timesteps     | 964020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.421    |
# | avg_norm_g          | 1.57     |
# | avg_norm_grads_f    | 1.24     |
# | avg_norm_k          | 1.41     |
# | avg_norm_k_dot_g    | 1.57     |
# | entropy             | 14.1     |
# | explained_variance  | -0.0632  |
# | fps                 | 477      |
# | loss                | -0.359   |
# | loss_bc             | -0       |
# | loss_f              | -0.502   |
# | loss_policy         | -0.502   |
# | loss_q              | 0.569    |
# | mean_episode_length | 330      |
# | mean_episode_reward | 129      |
# | norm_grads          | 19.4     |
# | norm_grads_policy   | 5.07     |
# | norm_grads_q        | 18.7     |
# | total_timesteps     | 966020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.532    |
# | avg_norm_g          | 4.99     |
# | avg_norm_grads_f    | 4.62     |
# | avg_norm_k          | 1.65     |
# | avg_norm_k_dot_g    | 5.22     |
# | entropy             | 4.79     |
# | explained_variance  | -0.207   |
# | fps                 | 477      |
# | loss                | 1.93     |
# | loss_bc             | -0       |
# | loss_f              | 0.26     |
# | loss_policy         | 0.26     |
# | loss_q              | 3.43     |
# | mean_episode_length | 361      |
# | mean_episode_reward | 150      |
# | norm_grads          | 44.8     |
# | norm_grads_policy   | 16.3     |
# | norm_grads_q        | 41.7     |
# | total_timesteps     | 968020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0328   |
# | avg_norm_g          | 2.98     |
# | avg_norm_grads_f    | 2.95     |
# | avg_norm_k          | 1.54     |
# | avg_norm_k_dot_g    | 3.61     |
# | entropy             | 3.25     |
# | explained_variance  | 0.708    |
# | fps                 | 478      |
# | loss                | 0.741    |
# | loss_bc             | -0       |
# | loss_f              | 0.339    |
# | loss_policy         | 0.339    |
# | loss_q              | 0.868    |
# | mean_episode_length | 358      |
# | mean_episode_reward | 153      |
# | norm_grads          | 16.5     |
# | norm_grads_policy   | 11.9     |
# | norm_grads_q        | 11.3     |
# | total_timesteps     | 970020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 25.3     |
# | avg_norm_grads_f    | 25.3     |
# | avg_norm_k          | 1.51     |
# | avg_norm_k_dot_g    | 30.2     |
# | entropy             | 2.17     |
# | explained_variance  | 0.855    |
# | fps                 | 478      |
# | loss                | 3.36     |
# | loss_bc             | -0       |
# | loss_f              | 1        |
# | loss_policy         | 1        |
# | loss_q              | 4.75     |
# | mean_episode_length | 344      |
# | mean_episode_reward | 134      |
# | norm_grads          | 75       |
# | norm_grads_policy   | 34.2     |
# | norm_grads_q        | 66.7     |
# | total_timesteps     | 972020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 7.71     |
# | avg_norm_grads_f    | 7.71     |
# | avg_norm_k          | 1.36     |
# | avg_norm_k_dot_g    | 7.22     |
# | entropy             | 1.87     |
# | explained_variance  | -2.04    |
# | fps                 | 478      |
# | loss                | 2.17     |
# | loss_bc             | -0       |
# | loss_f              | 0.848    |
# | loss_policy         | 0.848    |
# | loss_q              | 2.68     |
# | mean_episode_length | 354      |
# | mean_episode_reward | 140      |
# | norm_grads          | 40       |
# | norm_grads_policy   | 8.04     |
# | norm_grads_q        | 39.2     |
# | total_timesteps     | 974020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.201    |
# | avg_norm_g          | 1.31     |
# | avg_norm_grads_f    | 1.16     |
# | avg_norm_k          | 1.45     |
# | avg_norm_k_dot_g    | 1.33     |
# | entropy             | 3.46     |
# | explained_variance  | 0.711    |
# | fps                 | 478      |
# | loss                | 0.315    |
# | loss_bc             | -0       |
# | loss_f              | -0.093   |
# | loss_policy         | -0.093   |
# | loss_q              | 0.886    |
# | mean_episode_length | 363      |
# | mean_episode_reward | 152      |
# | norm_grads          | 8.15     |
# | norm_grads_policy   | 5.27     |
# | norm_grads_q        | 6.22     |
# | total_timesteps     | 976020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.681    |
# | avg_norm_g          | 2.3      |
# | avg_norm_grads_f    | 1.79     |
# | avg_norm_k          | 1.41     |
# | avg_norm_k_dot_g    | 2.29     |
# | entropy             | 13.5     |
# | explained_variance  | -0.016   |
# | fps                 | 478      |
# | loss                | -0.463   |
# | loss_bc             | -0       |
# | loss_f              | -0.742   |
# | loss_policy         | -0.742   |
# | loss_q              | 0.828    |
# | mean_episode_length | 343      |
# | mean_episode_reward | 151      |
# | norm_grads          | 27       |
# | norm_grads_policy   | 0.452    |
# | norm_grads_q        | 26.9     |
# | total_timesteps     | 978020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 0.611    |
# | avg_norm_grads_f    | 0.611    |
# | avg_norm_k          | 1.49     |
# | avg_norm_k_dot_g    | 0.614    |
# | entropy             | 1.98     |
# | explained_variance  | 0.97     |
# | fps                 | 478      |
# | loss                | 0.111    |
# | loss_bc             | -0       |
# | loss_f              | 0.0234   |
# | loss_policy         | 0.0234   |
# | loss_q              | 0.214    |
# | mean_episode_length | 314      |
# | mean_episode_reward | 137      |
# | norm_grads          | 10.7     |
# | norm_grads_policy   | 0.333    |
# | norm_grads_q        | 10.7     |
# | total_timesteps     | 980020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 26.8     |
# | avg_norm_grads_f    | 26.8     |
# | avg_norm_k          | 1.39     |
# | avg_norm_k_dot_g    | 25.4     |
# | entropy             | 2.13     |
# | explained_variance  | 0.926    |
# | fps                 | 479      |
# | loss                | 3.23     |
# | loss_bc             | -0       |
# | loss_f              | 0.639    |
# | loss_policy         | 0.639    |
# | loss_q              | 5.22     |
# | mean_episode_length | 335      |
# | mean_episode_reward | 134      |
# | norm_grads          | 44       |
# | norm_grads_policy   | 21       |
# | norm_grads_q        | 38.6     |
# | total_timesteps     | 982020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 2.84     |
# | avg_norm_grads_f    | 2.84     |
# | avg_norm_k          | 1.77     |
# | avg_norm_k_dot_g    | 2.84     |
# | entropy             | 4.64     |
# | explained_variance  | 0.769    |
# | fps                 | 479      |
# | loss                | 1.83     |
# | loss_bc             | -0       |
# | loss_f              | 0.357    |
# | loss_policy         | 0.357    |
# | loss_q              | 3.03     |
# | mean_episode_length | 353      |
# | mean_episode_reward | 137      |
# | norm_grads          | 35.9     |
# | norm_grads_policy   | 11       |
# | norm_grads_q        | 34.2     |
# | total_timesteps     | 984020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.23     |
# | avg_norm_g          | 3.36     |
# | avg_norm_grads_f    | 2.33     |
# | avg_norm_k          | 1.54     |
# | avg_norm_k_dot_g    | 3.3      |
# | entropy             | 2.46     |
# | explained_variance  | 0.268    |
# | fps                 | 479      |
# | loss                | 1.72     |
# | loss_bc             | -0       |
# | loss_f              | -0.278   |
# | loss_policy         | -0.278   |
# | loss_q              | 4.04     |
# | mean_episode_length | 362      |
# | mean_episode_reward | 149      |
# | norm_grads          | 55.4     |
# | norm_grads_policy   | 14.6     |
# | norm_grads_q        | 53.5     |
# | total_timesteps     | 986020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0316   |
# | avg_norm_g          | 1.44     |
# | avg_norm_grads_f    | 1.41     |
# | avg_norm_k          | 1.25     |
# | avg_norm_k_dot_g    | 1.46     |
# | entropy             | 1.8      |
# | explained_variance  | 0.963    |
# | fps                 | 479      |
# | loss                | 0.371    |
# | loss_bc             | -0       |
# | loss_f              | 0.125    |
# | loss_policy         | 0.125    |
# | loss_q              | 0.528    |
# | mean_episode_length | 356      |
# | mean_episode_reward | 136      |
# | norm_grads          | 12.7     |
# | norm_grads_policy   | 4.75     |
# | norm_grads_q        | 11.7     |
# | total_timesteps     | 988020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 26.5     |
# | avg_norm_grads_f    | 26.5     |
# | avg_norm_k          | 1.59     |
# | avg_norm_k_dot_g    | 26.5     |
# | entropy             | 3.98     |
# | explained_variance  | -1.24    |
# | fps                 | 479      |
# | loss                | 161      |
# | loss_bc             | -0       |
# | loss_f              | 2.67     |
# | loss_policy         | 2.67     |
# | loss_q              | 316      |
# | mean_episode_length | 352      |
# | mean_episode_reward | 137      |
# | norm_grads          | 319      |
# | norm_grads_policy   | 19.2     |
# | norm_grads_q        | 318      |
# | total_timesteps     | 990020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 1.1      |
# | avg_norm_g          | 3.58     |
# | avg_norm_grads_f    | 2.79     |
# | avg_norm_k          | 1.6      |
# | avg_norm_k_dot_g    | 3.61     |
# | entropy             | 2.22     |
# | explained_variance  | 0.528    |
# | fps                 | 479      |
# | loss                | 2.78     |
# | loss_bc             | -0       |
# | loss_f              | -0.221   |
# | loss_policy         | -0.221   |
# | loss_q              | 6.04     |
# | mean_episode_length | 337      |
# | mean_episode_reward | 124      |
# | norm_grads          | 84.1     |
# | norm_grads_policy   | 10.8     |
# | norm_grads_q        | 83.4     |
# | total_timesteps     | 992020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 3.37     |
# | avg_norm_grads_f    | 3.37     |
# | avg_norm_k          | 1.12     |
# | avg_norm_k_dot_g    | 3.37     |
# | entropy             | 0.38     |
# | explained_variance  | -0.497   |
# | fps                 | 479      |
# | loss                | 3.61     |
# | loss_bc             | -0       |
# | loss_f              | 0.000731 |
# | loss_policy         | 0.000731 |
# | loss_q              | 7.23     |
# | mean_episode_length | 337      |
# | mean_episode_reward | 119      |
# | norm_grads          | 26.5     |
# | norm_grads_policy   | 0.0554   |
# | norm_grads_q        | 26.5     |
# | total_timesteps     | 994020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.376    |
# | avg_norm_g          | 1.56     |
# | avg_norm_grads_f    | 1.26     |
# | avg_norm_k          | 1.41     |
# | avg_norm_k_dot_g    | 1.56     |
# | entropy             | 13.1     |
# | explained_variance  | -0.273   |
# | fps                 | 479      |
# | loss                | -0.369   |
# | loss_bc             | -0       |
# | loss_f              | -0.47    |
# | loss_policy         | -0.47    |
# | loss_q              | 0.464    |
# | mean_episode_length | 352      |
# | mean_episode_reward | 124      |
# | norm_grads          | 8.66     |
# | norm_grads_policy   | 4.04     |
# | norm_grads_q        | 7.66     |
# | total_timesteps     | 996020   |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.603    |
# | avg_norm_g          | 2.57     |
# | avg_norm_grads_f    | 2.07     |
# | avg_norm_k          | 1.38     |
# | avg_norm_k_dot_g    | 2.57     |
# | entropy             | 5.15     |
# | explained_variance  | -0.566   |
# | fps                 | 480      |
# | loss                | 1.84     |
# | loss_bc             | -0       |
# | loss_f              | 0.318    |
# | loss_policy         | 0.318    |
# | loss_q              | 3.15     |
# | mean_episode_length | 335      |
# | mean_episode_reward | 127      |
# | norm_grads          | 10.9     |
# | norm_grads_policy   | 0.145    |
# | norm_grads_q        | 10.9     |
# | total_timesteps     | 998020   |
# ----------------------------------

# %%
#evaluate the model
evaluate_policy(model, env, n_eval_episodes=5, render=True)
env.close()
